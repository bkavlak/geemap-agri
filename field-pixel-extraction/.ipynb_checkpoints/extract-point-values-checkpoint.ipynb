# %% [markdown]
# <a href="https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/43_extract_values_to_points.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
import os
import ee
import geemap
import geopandas

# %%
import os
import ee
import geemap
import geopandas

# Get Target Polygon File
polygon_collection = ee.FeatureCollection('users/batuhankavlak4/DOKTAR_SAMPLE/CARGILL_DATASET_2020_TEYITLI_v01')
# Convert TarlaId in a Python list
polygon_collection_list = polygon_collection.aggregate_array('TarlaId');
polygon_collection_list_py = polygon_collection_list.getInfo()

# LOOP 1 - OVER POLYGONS
for field_id in polygon_collection_list_py:
    
    # Get target polygon
    polygon_feature = ee.Feature(polygon_collection_list_py.filter(ee.Filter.eq('TarlaId', field_id)).first())
    
    # Add Earth Engine dataset
    s2_col = ee.ImageCollection("COPERNICUS/S2_SR") \
    .filterBounds(polygon_feature.geometry()) \
    .filterDate('2020-04-01', '2020-11-30') \
    .filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', 20)) \
    .select(['B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B11', 'B12']);
    
    # Extract Pixels as Point
    polygon_feature = ee.Image(s2_col.mean().select(['B2'])).sample(**{
        'region': polygon_feature.geometry(),
        'geometries': True,  # if you want points,
        'scale': 10
    });
    
    # Get PRODUCT_ID in a Python list
    collection_list = s2_col.aggregate_array('PRODUCT_ID');
    collection_list_py = collection_list.getInfo();
    
    # LOOP 2 - OVER IMAGES
    for product_name in collection_list_py:
        # Add Earth Engine dataset
        s2_image = ee.Image(s2_col \
                            .filter(ee.Filter.eq('PRODUCT_ID', product_name)) \
                            .first());
        output_dir = os.path.expanduser('./csv/')
        out_csv = os.path.join(output_dir, product_name + '_' + field_id + '.csv')
        geemap.extract_values_to_points(polygon_feature, s2_image, out_csv, scale = 10)

# %%
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…

# %%
polygon_collection = ee.FeatureCollection('users/batuhankavlak4/DOKTAR_SAMPLE/CARGILL_DATASET_2020_TEYITLI_v01')
Map.addLayer(polygon_collection, {}, "CARGILL_SET")
polygon_feature = ee.Feature(polygon_collection.filter(ee.Filter.eq('TarlaId', 324768)).first())

# %%
polygon_feature.getInfo()
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[33.256345740630536, 37.709413657947884],
#     [33.25719744826813, 37.70466027001103],
#     [33.25878488868583, 37.70483860939703],
#     [33.259944236031465, 37.70965442231666],
#     [33.256345740630536, 37.709413657947884]]]},
#  'id': '0000000000000000005f',
#  'properties': {'TarlaId': 324768}}

# %%
# Add Earth Engine dataset
s2_col = ee.ImageCollection("COPERNICUS/S2_SR") \
    .filterBounds(polygon_feature.geometry()) \
    .filterDate('2020-04-01', '2020-11-30') \
    .filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', 20)) \
    .select(['B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B11', 'B12']);

# %%
polygon_feature = ee.Image(s2_col.mean().select(['B2'])).sample(**{
  'region': polygon_feature.geometry(),
  'geometries': True,  # if you want points,
  'scale': 10
});

# %%
# Get PRODUCT_ID in a Python list
collection_list = s2_col.aggregate_array('PRODUCT_ID');
collection_list_py = collection_list.getInfo()

# %% [markdown]
# Export pixel values as a csv

# %%
# %%time
# Extract Values in a Loop
for product_name in collection_list_py:
    # Add Earth Engine dataset
    s2_image = ee.Image(s2_col \
                        .filter(ee.Filter.eq('PRODUCT_ID', product_name)) \
                        .first());
    output_dir = os.path.expanduser('./csv/')
    out_csv = os.path.join(output_dir, product_name + '_TarlaId324768' + '.csv')
    geemap.extract_values_to_points(polygon_feature, s2_image, out_csv, scale = 10)
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/fc712a628323e3794c0a7b36b63dde45-8fe94cf202ece23193ed390ac2dadf6d:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2A_MSIL2A_20200411T083601_N0214_R064_T36SWG_20200411T120406_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/dc5e0c7b3af4d728c78c543132886fdd-6a772399223ce326f77af23d558e809d:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2B_MSIL2A_20200413T082559_N0214_R021_T36SWG_20200413T115830_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/40758a44bc6cdf799518e8620ff19980-9636610bbfdc20ad272b9152a2af297d:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2B_MSIL2A_20200426T083559_N0214_R064_T36SWG_20200426T123506_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/cf6d62b65c15e3dec535ee0dfc893e2d-598dbd3e71b15b812bd3b3f98a9e7e5b:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2A_MSIL2A_20200428T082601_N0214_R021_T36SWG_20200428T113331_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/4fcf624dc64e4ce88b4673f93c615ec1-d51646ac5d5f16440ede5932d84e6117:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2B_MSIL2A_20200513T082559_N0214_R021_T36SWG_20200513T115741_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/cced91880e676656ce7600940b069b71-568ee5c5510336a320dfbe214561176c:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2B_MSIL2A_20200516T083559_N0214_R064_T36SWG_20200516T123826_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/5bd2dca928bf34cf8387eb854b7dd49d-76867811b7ced576eb520fe90dc0517f:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2A_MSIL2A_20200518T082611_N0214_R021_T36SWG_20200518T111906_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/253d6e7ddc827ce50fb2591588705eb3-5b6166a1f135ce1275bfaf38ab8cb8d8:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2A_MSIL2A_20200521T083611_N0214_R064_T36SWG_20200521T113652_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/7813bab860c0ea399c0459b33cc53fac-562333b85ce077b800de1afeeb5aa1c1:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2A_MSIL2A_20200528T082611_N0214_R021_T36SWG_20200528T113801_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/86f1504c5a97deecb69873c40ad8173a-9f307db63fd0cf5853c8a99e6ce083b9:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2B_MSIL2A_20200605T083559_N0214_R064_T36SWG_20200605T131458_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/72c804dc21f3e27bc3dbe401e9c189a7-3aa4ecf39a3de1a9e4756b7a5583d971:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2A_MSIL2A_20200607T082611_N0214_R021_T36SWG_20200607T115845_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/c0d2137d31344d6b4aecedf3d81475fc-ad84d592ef68b31ae17f745ba0881521:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2A_MSIL2A_20200610T083611_N0214_R064_T36SWG_20200610T112436_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/e0a4fcd13b85f043c8ac3de5ac2501c0-600496970a3e8a048084a8a9c449067a:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2B_MSIL2A_20200612T082609_N0214_R021_T36SWG_20200612T105411_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/e8bd1e7af49677d5e51eed239aab457f-fc93f94a73ca585de6e15143e4344c5d:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2B_MSIL2A_20200612T082609_N0214_R021_T36SWG_20200612T115932_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/870c6f83866be4196df9b93da56912c8-d98bc8d3f8b7bc959b00ff2f28d84630:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2B_MSIL2A_20200615T083559_N0214_R064_T36SWG_20200615T123803_TarlaId324768.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/9166d546dad9b41186fb84ccc884a03d-f755e7f20cdb0c3fe9b594afecdb4223:getFeatures
# Please wait ...
# Data downloaded to /geemap/data/PC/temp/earth-extraction/csv/S2B_MSIL2A_20